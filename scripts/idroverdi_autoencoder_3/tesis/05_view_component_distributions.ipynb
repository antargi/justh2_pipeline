# %%
from IPython.display import Image, display
from pathlib import Path

PLOTS_DIR = Path('/home/aninotna/magister/tesis/justh2_pipeline/plots/results')

print("\n" + "="*80)
print("GRÁFICOS DE DISTRIBUCIÓN DE COMPONENTES DEL IRT")
print("Escenario: SSP585 | Período: 2090-2100")
print("="*80)
# Out:
# ...
# GRÁFICOS DE DISTRIBUCIÓN DE COMPONENTES DEL IRT
# Escenario: SSP585 | Período: 2090-2100
# ...

# %% [markdown]
# ## Modelo VAE

# %%
vae_file = PLOTS_DIR / 'irt_component_distributions_VAE.png'
if vae_file.exists():
    print(f"\n✓ Cargando: {vae_file.name}")
    display(Image(filename=str(vae_file)))
else:
    print(f"✗ Archivo no encontrado: {vae_file}")
# Out:
# ✓ Cargando: irt_component_distributions_VAE.png

# %% [markdown]
# ## Modelo AE

# %%
ae_file = PLOTS_DIR / 'irt_component_distributions_AE.png'
if ae_file.exists():
    print(f"\n✓ Cargando: {ae_file.name}")
    display(Image(filename=str(ae_file)))
else:
    print(f"✗ Archivo no encontrado: {ae_file}")
# Out:
# ✓ Cargando: irt_component_distributions_AE.png

# %% [markdown]
# ## Resumen Estadístico
#
# ### VAE - SSP585
# - **A** (Anomalía): μ=0.4992, mediana=0.4992, σ=0.2887
# - **S_D** (Desplazamiento): μ=0.4931, mediana=0.4556, σ=0.1170
# - **S_C** (Estabilidad): μ=0.4240, mediana=0.3860, σ=0.1498
# - **S_E** (Expansión): μ=1.1255, mediana=1.1543, σ=0.2439
# - **S_H₂** (Energía): μ=0.5941, mediana=0.5008, σ=0.1874
#   - Colapso H₂ (S_H₂ < 0.1): 0.0%
#
# ### AE - SSP585
# - **A** (Anomalía): μ=0.4992, mediana=0.4992, σ=0.2887
# - **S_D** (Desplazamiento): μ=0.3149, mediana=0.3121, σ=0.0545
# - **S_C** (Estabilidad): μ=0.3431, mediana=0.3349, σ=0.0942
# - **S_E** (Expansión): μ=1.0115, mediana=0.9741, σ=0.0667
# - **S_H₂** (Energía): μ=0.5941, mediana=0.5008, σ=0.1874
#   - Colapso H₂ (S_H₂ < 0.1): 0.0%
