# %%
import cdsapi
import os
import xarray as xr
import os

# %% [markdown]
# # SSP245

# %% [markdown]
# ## access_cm2

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "access_cm2",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-08 23:36:58,474 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-08 23:36:59,293 INFO Request ID is 61adb86e-49c4-4f55-b1ee-873d2c3d238b
# 2025-09-08 23:36:59,576 INFO status has been updated to accepted
# 2025-09-08 23:37:14,326 INFO status has been updated to running
# 2025-09-08 23:37:33,989 INFO status has been updated to successful
# '21b24af79f17d643e0df4ceb105e076e.zip'

# %% [markdown]
# ## canesm5

# %%
dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "canesm5",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-08 23:43:21,806 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-08 23:43:22,921 INFO Request ID is 0d759690-c315-43ff-98de-2cdc4b1918dc
# 2025-09-08 23:43:23,185 INFO status has been updated to accepted
# 2025-09-08 23:43:37,918 INFO status has been updated to running
# 2025-09-08 23:43:57,476 INFO status has been updated to successful
# 'a3f0179b2ebd08db5a0da493fda2bd05.zip'

# %% [markdown]
# ## kace_1_0_g

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "kace_1_0_g",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-08 23:53:08,614 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-08 23:53:10,137 INFO Request ID is 9834cb1e-7809-4a18-ad28-c7055f686ec7
# 2025-09-08 23:53:10,445 INFO status has been updated to accepted
# 2025-09-08 23:53:25,414 INFO status has been updated to running
# 2025-09-08 23:54:02,362 INFO status has been updated to successful
# 'f0cd4d8256afa047a10d710e8baef0e3.zip'

# %% [markdown]
# ## inm_cm4_8

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "inm_cm4_8",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-09 00:23:36,056 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-09 00:23:36,977 INFO Request ID is 64d1860b-6166-4f69-bbbf-a0d270fe5a40
# 2025-09-09 00:23:37,261 INFO status has been updated to accepted
# 2025-09-09 00:23:51,909 INFO status has been updated to running
# 2025-09-09 00:24:11,486 INFO status has been updated to successful
# 'e20ed27b5eb120ff9b8cb1be88b45d87.zip'

# %% [markdown]
# ## cams cms

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "cams_csm1_0",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-09 00:29:02,601 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-09 00:29:03,743 INFO Request ID is a3f0d1eb-1e64-4a22-9d40-e9e9efde187d
# 2025-09-09 00:29:04,026 INFO status has been updated to accepted
# 2025-09-09 00:29:18,897 INFO status has been updated to running
# 2025-09-09 00:29:26,781 INFO status has been updated to accepted
# 2025-09-09 00:29:38,557 INFO status has been updated to successful
# '9dec73740ff5747da713cdff0f0540c.zip'

# %% [markdown]
# ## mpi_esm1_2_lr

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "mpi_esm1_2_lr",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 21:55:59,130 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 21:56:00,079 INFO Request ID is 8d0aa1fe-1b7d-4e80-97fb-13d041ae445b
# 2025-09-14 21:56:00,364 INFO status has been updated to accepted
# 2025-09-14 21:56:09,678 INFO status has been updated to running
# 2025-09-14 21:56:15,051 INFO status has been updated to accepted
# 2025-09-14 21:56:22,989 INFO status has been updated to running
# 2025-09-14 21:56:34,664 INFO status has been updated to successful
# 'ab890db8d1c70194c62b042df1bfc2ae.zip'

# %% [markdown]
# ## gfdl_esm4

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp2_4_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "gfdl_esm4",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 21:53:31,190 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 21:53:32,259 INFO Request ID is 1a454974-9244-4dbc-8efa-7f18dd5a3d4d
# 2025-09-14 21:53:32,533 INFO status has been updated to accepted
# 2025-09-14 21:53:41,913 INFO status has been updated to running
# 2025-09-14 21:53:47,549 INFO status has been updated to accepted
# 2025-09-14 21:54:07,377 INFO status has been updated to successful
# 'e6e681448620650748abcb6427850d6.zip'

# %% [markdown]
# # SSP370

# %% [markdown]
# # gfdl_esm4

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp3_7_0",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "gfdl_esm4",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 22:00:05,304 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 22:00:06,418 INFO Request ID is f9debe67-2a6d-4efa-9698-6cd347204c59
# 2025-09-14 22:00:06,682 INFO status has been updated to accepted
# 2025-09-14 22:00:29,163 INFO status has been updated to running
# 2025-09-14 22:00:58,173 INFO status has been updated to successful
# 'ec15e3be275f8aad954c7a0f384d6fb0.zip'

# %% [markdown]
# ## access_cm2

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp3_7_0",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "access_cm2",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 22:01:37,718 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 22:01:38,793 INFO Request ID is e195744d-81e7-4e0a-a18e-4edd66c0675f
# 2025-09-14 22:01:39,088 INFO status has been updated to accepted
# 2025-09-14 22:01:53,758 INFO status has been updated to successful
# '58250fbf242767467ebc2ec3f901c7d4.zip'

# %% [markdown]
# # SSP585

# %% [markdown]
# # gfdl_esm4

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp5_8_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "gfdl_esm4",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 22:04:12,018 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 22:04:14,609 INFO Request ID is 2a28ba44-e206-4b32-9783-517795df1863
# 2025-09-14 22:04:14,879 INFO status has been updated to accepted
# 2025-09-14 22:04:24,496 INFO status has been updated to running
# 2025-09-14 22:04:49,365 INFO status has been updated to successful
# '7a45ff6c380b33a0f37d43f5fb4ab161.zip'

# %% [markdown]
# ## access_cm2

# %%
import cdsapi

dataset = "projections-cmip6"
request = {
    "temporal_resolution": "monthly",
    "experiment": "ssp5_8_5",
    "variable": "surface_downwelling_shortwave_radiation",
    "model": "access_cm2",
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "year": [
        "2015", "2016", "2017",
        "2018", "2019", "2020",
        "2021", "2022", "2023",
        "2024", "2025", "2026",
        "2027", "2028", "2029",
        "2030", "2031", "2032",
        "2033", "2034", "2035",
        "2036", "2037", "2038",
        "2039", "2040", "2041",
        "2042", "2043", "2044",
        "2045", "2046", "2047",
        "2048", "2049", "2050",
        "2051", "2052", "2053",
        "2054", "2055", "2056",
        "2057", "2058", "2059",
        "2060", "2061", "2062",
        "2063", "2064", "2065",
        "2066", "2067", "2068",
        "2069", "2070", "2071",
        "2072", "2073", "2074",
        "2075", "2076", "2077",
        "2078", "2079", "2080",
        "2081", "2082", "2083",
        "2084", "2085", "2086",
        "2087", "2088", "2089",
        "2090", "2091", "2092",
        "2093", "2094", "2095",
        "2096", "2097", "2098",
        "2099", "2100"
    ]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-09-14 22:06:22,347 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-09-14 22:06:23,381 INFO Request ID is c4c86bb2-5f11-48ab-a920-7ea4df83aca8
# 2025-09-14 22:06:23,730 INFO status has been updated to accepted
# 2025-09-14 22:06:38,320 INFO status has been updated to successful
# '5fd599612374ad4c83773c4bdc8c7607.zip'
