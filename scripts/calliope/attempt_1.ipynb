# %%
import calliope

# %%
model_path = "/home/aninotna/magister/tesis/justh2_pipeline/scripts/calliope/model_config.yml"
model = calliope.Model(
    model_path,
    override_dict={
        "run.objective_options.cost_class": {"monetary": 1}
    }
)
model.inputs
# Out:
# /home/aninotna/.conda/envs/calliope_env/lib/python3.11/site-packages/calliope/exceptions.py:60: ModelWarning:
#
# Possible issues found during model processing:
#  * Not building the link S_E_JUNCAL_PORTILLO,HNOS_CLARK because one or both of its locations have been removed from the model by setting ``exists: false``
#  * Not building the link TAP_CALEU,S_E_CALEU because one or both of its locations have been removed from the model by setting ``exists: false``
#  * Not building the link TAP_EL_MANZANO_(ENEL_DISTRIBUCION),S_E_EL_MANZANO_(ENEL_DISTRIBUCION) because one or both of its locations have been removed from the model by setting ``exists: false``
#  * Not building the link TAP_LOS_MAQUIS,S_E_LOS_MAQUIS because one or both of its locations have been removed from the model by setting ``exists: false``
#  * Not building the link TAP_OFF_DOÑA_CARMEN,S_E_DOÑA_CARMEN because one or both of its locations have been removed from the model by setting ``exists: false``
# ...

# %%
model.run()
model.save("my_model/results.nc")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.run()
#       2 model.save("my_model/results.nc")
#
# NameError: name 'model' is not defined
